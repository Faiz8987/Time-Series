# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
aa=pd.read_csv("C:\\Users\\lenovo\\Downloads\\AirPassengers.csv",parse_dates=['Month'],index_col='Month')

# %%
aa.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
aa.dtypes
# Out:
# #Passengers    int64
# dtype: object

# %%
aa.columns
# Out:
# Index(['#Passengers'], dtype='object')

# %%
aa.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df1=aa['1951-04-01':'1952-03-01']

# %%
df1.head()
# Out:
#             #Passengers
# Month
# 1951-04-01          163
# 1951-05-01          172
# 1951-06-01          178
# 1951-07-01          199
# 1951-08-01          199

# %%
df1.loc['1951-04-01',('#Passengers')]
# Out:
# 163

# %%
df1.iloc[0:5]
# Out:
#             #Passengers
# Month
# 1951-04-01          163
# 1951-05-01          172
# 1951-06-01          178
# 1951-07-01          199
# 1951-08-01          199

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
aa.plot()
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.plot(aa,color='cyan')
plt.show()

# %%
dec=seasonal_decompose(aa,model='multipicative')

# %%
dec.plot()
plt.show()

# %%
aa_log=aa.copy()

# %%
aa_log['#Passengers']=np.log(aa)

# %%
plt.plot(aa)

# %%
plt.plot(aa_log)

# %%
plt.subplot(2,1,1)
plt.plot(aa)
plt.title('original')
plt.subplot(2,1,2)
plt.plot(aa_log)
plt.title('log')


plt.show()

# %%
apple=pd.read_csv("C:\\Users\\lenovo\\Downloads\\HistoricalQuotes.csv",parse_dates=['Date'],index_col=['Date'])

# %%
apple.head()
# Out:
#         Date   Close/Last     Volume    Open    High     Low
# 0  2/28/2020       273.36  106721200  257.26  278.41  256.37
# 1  2/27/2020       273.52   80151380  281.10  286.00  272.96
# 2  2/26/2020       292.65   49678430  286.53  297.88  286.50
# 3  2/25/2020       288.08   57668360  300.95  302.53  286.13
# 4  2/24/2020       298.18   55548830  297.26  304.18  289.23

# %%
apple.dtypes
# Out:
#  Close/Last    float64
#  Volume          int64
#  Open          float64
#  High          float64
#  Low           float64
# dtype: object

# %%
apple.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  2518.000000  2.518000e+03  2518.000000  2518.000000  2518.000000
# mean    114.769627  7.258009e+07   114.728558   115.766541   113.690659
# std      60.662349  5.663113e+07    60.546889    61.134394    60.085100
# min      29.840000  1.136205e+07    29.390000    29.930000    28.460000
# 25%      66.825000  3.053026e+07    66.877500    67.472500    66.375000
# 50%     101.090000  5.295469e+07   101.115000   102.085000   100.350000
# 75%     154.630000  9.861006e+07   154.610000   155.735000   153.325000
# max     327.200000  4.624423e+08   324.740000   327.850000   323.350000

# %%
type(apple.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
aa.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
apple.columns=['close','volume','open','high','low']

# %%
apple.head()
# Out:
#              close     volume    open    high     low
# Date
# 2020-02-28  273.36  106721200  257.26  278.41  256.37
# 2020-02-27  273.52   80151380  281.10  286.00  272.96
# 2020-02-26  292.65   49678430  286.53  297.88  286.50
# 2020-02-25  288.08   57668360  300.95  302.53  286.13
# 2020-02-24  298.18   55548830  297.26  304.18  289.23

# %%
apple.columns
# Out:
# Index(['close', 'volume', 'open', 'high', 'low'], dtype='object')

# %%
apple.loc['2017-01'].close.mean()
# Out:
# 119.57000000000001

# %%
plt.plot(apple['close'])
plt.show()

# %%
apple.loc['2017-12-01':'2017-12-31']
# Out:
#              close    volume    open    high     low
# Date
# 2017-12-29  169.23  25938760  170.52  170.59  169.22
# 2017-12-28  171.08  16412270  171.00  171.85  170.48
# 2017-12-27  170.60  21477380  170.10  170.78  169.71
# 2017-12-26  170.57  33113340  170.80  171.47  169.68
# 2017-12-22  175.01  16339690  174.68  175.42  174.50
# 2017-12-21  175.01  20848660  174.17  176.02  174.10
# 2017-12-20  174.35  23451420  174.87  175.42  173.25
# 2017-12-19  174.54  27393660  175.03  175.39  174.09
# 2017-12-18  176.42  29385650  174.88  177.20  174.86
# 2017-12-15  173.97  40122100  173.63  174.17  172.46
# 2017-12-14  172.22  20442740  172.40  173.13  171.65
# 2017-12-13  172.27  23402510  172.50  173.54  172.00
# 2017-12-12  171.70  19088170  172.15  172.39  171.46
# 2017-12-11  172.67  34260890  169.20  172.89  168.79
# 2017-12-08  169.37  23285760  170.49  171.00  168.82
# 2017-12-07  169.32  25656110  169.03  170.44  168.91
# 2017-12-06  169.01  28397810  167.50  170.20  166.46
# ...

# %%
apple['close'].resample('W').mean()
# Out:
# Date
# 2010-03-07     30.1960
# 2010-03-14     31.9720
# 2010-03-21     31.9800
# 2010-03-28     32.5740
# 2010-04-04     33.5425
#                 ...
# 2020-02-02    316.8720
# 2020-02-09    318.8400
# 2020-02-16    323.6360
# 2020-02-23    318.9925
# 2020-03-01    285.1580
# Freq: W-SUN, Name: close, Length: 522, dtype: float64

# %%
jan=apple.loc['2017-01']

# %%
jan.resample('D').mean()
# Out:
#              close      volume    open    high     low
# Date
# 2017-01-03  116.15  28769220.0  115.80  116.33  114.76
# 2017-01-04  116.02  21081620.0  115.85  116.51  115.75
# 2017-01-05  116.61  22115100.0  115.92  116.86  115.81
# 2017-01-06  117.91  31714820.0  116.78  118.16  116.47
# 2017-01-07     NaN         NaN     NaN     NaN     NaN
# 2017-01-08     NaN         NaN     NaN     NaN     NaN
# 2017-01-09  118.99  33420290.0  117.95  119.43  117.94
# 2017-01-10  119.11  24432660.0  118.77  119.38  118.30
# 2017-01-11  119.75  27453130.0  118.74  119.93  118.60
# 2017-01-12  119.25  27057550.0  118.90  119.30  118.21
# 2017-01-13  119.04  26083030.0  119.11  119.62  118.81
# 2017-01-14     NaN         NaN     NaN     NaN     NaN
# 2017-01-15     NaN         NaN     NaN     NaN     NaN
# 2017-01-16     NaN         NaN     NaN     NaN     NaN
# 2017-01-17  120.00  34412090.0  118.34  120.24  118.22
# 2017-01-18  119.99  23687350.0  120.00  120.50  119.71
# ...

# %%
jan
# Out:
#              close    volume    open    high     low
# Date
# 2017-01-31  121.35  47767760  121.15  121.39  120.62
# 2017-01-30  121.63  30327110  120.93  121.63  120.66
# 2017-01-27  121.95  20495340  122.14  122.35  121.60
# 2017-01-26  121.94  26320740  121.67  122.44  121.60
# 2017-01-25  121.88  32417410  120.42  122.10  120.28
# 2017-01-24  119.97  23191150  119.55  120.10  119.50
# 2017-01-23  120.08  21982000  120.00  120.81  119.77
# 2017-01-20  120.00  29922650  120.45  120.45  119.73
# 2017-01-19  119.78  25554290  119.40  120.09  119.37
# 2017-01-18  119.99  23687350  120.00  120.50  119.71
# 2017-01-17  120.00  34412090  118.34  120.24  118.22
# 2017-01-13  119.04  26083030  119.11  119.62  118.81
# 2017-01-12  119.25  27057550  118.90  119.30  118.21
# 2017-01-11  119.75  27453130  118.74  119.93  118.60
# 2017-01-10  119.11  24432660  118.77  119.38  118.30
# 2017-01-09  118.99  33420290  117.95  119.43  117.94
# 2017-01-06  117.91  31714820  116.78  118.16  116.47
# ...

# %%
apple.resample('M').mean()
# Out:
#                  close        volume        open        high         low
# Date
# 2010-03-31   31.916087  1.316403e+08   31.829130   32.097391   31.611739
# 2010-04-30   35.878095  1.466239e+08   35.859048   36.162381   35.445714
# 2010-05-31   35.923000  2.254797e+08   35.998000   36.517500   34.974000
# 2010-06-30   37.307727  1.887870e+08   37.483636   37.843182   36.912273
# 2010-07-31   36.420952  1.859430e+08   36.497619   36.923333   35.870476
# ...                ...           ...         ...         ...         ...
# 2019-10-31  235.286522  2.707181e+07  234.929565  236.969130  232.945217
# 2019-11-30  262.520500  2.244611e+07  261.694000  263.461500  260.242000
# 2019-12-31  276.525714  2.851768e+07  275.391429  277.883810  273.868095
# 2020-01-31  311.916190  3.500061e+07  311.170952  314.326190  308.831429
# 2020-02-29  311.270526  3.974859e+07  310.313684  315.252632  306.726316
#
# [120 rows x 5 columns]
